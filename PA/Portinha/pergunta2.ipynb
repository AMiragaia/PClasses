# %%
#Quais setores da economia foram mais afetados durante a pandemia em termos de endividamento?
#Para responder a esta questão vamos analisar o endividamento de empresas de varios setores para perceber quais foram os mais afetados.
#Para ajudar na compreensão criamos um gráfico com toda a informação necessária.
# Import necessary libraries
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np

# Function to load data
def load_data(filename):
    df = pd.read_excel(filename, skiprows=7,skipfooter=25)  # jumps the first 7 rows
    return df

# Function to clean data
def clean_data(df):
    
    # Extract the desired rows and columns
    data = df.iloc[12:16, 1:12]
    
    return data
# Function to write DataFrame to a JSON file
def write_to_json(df, filename):
    df.to_json(filename, orient='index')

# Main function
def main():
    # Load data
    filename = 'questao2.xlsx'
    data = load_data(filename)

    # Clean data
    cleaned_data = clean_data(data)


    # Prepare the data
    x = data['Unnamed: 0'].values
    
    y2 = data['Indústrias transformadoras e extrativas'].values
    y3 = data['Construção'].values
    y4 = data['Comércio por grosso e a retalho (...)'].values
    y5 = data['Transporte e armazenagem'].values
    y6 = data['Alojamento, restauração e similares'].values
    y7 = data['Atividade de Informação e comunicação'].values
    y8 = data['Atividades de consultoria, técnicas e administrativas'].values
    y9 = data['Educação, saúde, apoio social, atividades artísticas (...)'].values
    y10 = data['Eletricidade, gás e água'].values
    y11 = data['Atividades imobiliárias'].values
    
    
    # Plot the data
    
    plt.plot(x, y2, label='Indústrias transformadoras e extrativas')
    plt.plot(x, y10, label='Eletricidade, gás e água')
    plt.plot(x, y3, label ='Construção')
    plt.plot(x, y4, label ='Comércio por grosso e a retalho (...)')
    plt.plot(x, y5, label ='Transporte e armazenagem')
    plt.plot(x, y6, label ='Alojamento, restauração e similares')
    plt.plot(x, y7, label ='Atividade de Informação e comunicação')
    plt.plot(x, y11, label ='Atividades imobiliárias')
    plt.plot(x, y8, label ='Atividades de consultoria, técnicas e administrativas')
    plt.plot(x, y9, label ='Educação, saúde, apoio social, atividades artísticas (...)')
    
    # Set labels and title
    plt.xlabel('Year')
    plt.ylabel('Value')
    plt.title('Economic Activity Over the Years')
    
    # Add legend
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    
    # Display the graph
    plt.show()

    data = data[data['Unnamed: 0'] >= 2018]  # Replace 'Unnamed: 0' with your column name for years
    x = data['Unnamed: 0'].values  # Now, 'x' will only contain years from 2018 onwards

    y2 = data['Indústrias transformadoras e extrativas'].values
    y3 = data['Construção'].values
    y4 = data['Comércio por grosso e a retalho (...)'].values
    y5 = data['Transporte e armazenagem'].values
    y6 = data['Alojamento, restauração e similares'].values
    y7 = data['Atividade de Informação e comunicação'].values
    y8 = data['Atividades de consultoria, técnicas e administrativas'].values
    y9 = data['Educação, saúde, apoio social, atividades artísticas (...)'].values
    y10 = data['Eletricidade, gás e água'].values
    y11 = data['Atividades imobiliárias'].values
    
    
    # Plot the data
    
    plt.plot(x, y2, label='Indústrias transformadoras e extrativas')
    plt.plot(x, y10, label='Eletricidade, gás e água')
    plt.plot(x, y3, label ='Construção')
    plt.plot(x, y4, label ='Comércio por grosso e a retalho (...)')
    plt.plot(x, y5, label ='Transporte e armazenagem')
    plt.plot(x, y6, label ='Alojamento, restauração e similares')
    plt.plot(x, y7, label ='Atividade de Informação e comunicação')
    plt.plot(x, y11, label ='Atividades imobiliárias')
    plt.plot(x, y8, label ='Atividades de consultoria, técnicas e administrativas')
    plt.plot(x, y9, label ='Educação, saúde, apoio social, atividades artísticas (...)')
    
    # Set labels and title
    plt.xlabel('Year')
    plt.ylabel('Value')
    plt.title('Economic Activity Over the Years')
    
    # Add legend
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    # Set the x-axis tick locations and labels
    plt.xticks(x, x.astype(int))
    # Display the graph
    plt.show()


# Run the main function
if __name__ == '__main__':
    main()
#Podemos ver que os setores que mais sofreram foram da Atividade de Informação e comunicação e da Eletricidade,gás e água.
